# %%
import os
os.makedirs("plots", exist_ok=True)
import numpy as np
import matplotlib.pyplot as plt

from analysis_functions import (
    plot_metrics,
    fourier_components,
    analyze_unembd,
    plot_metrics_progress_measure,
    plot_metrics_progress_measure_wd0
)

# %%
plot_metrics()
plt.show()

# %%
fourier_components()
plt.show()
# Out:
# Top 7 peaks, $W_E$ cos: [51, 43, 37, 39, 27, 33, 6]
# Top 7 peaks, $W_E$ sin: [51, 37, 43, 27, 39, 6, 33]
# Top 7 peaks, $W_L$ cos: [37, 51, 43, 8, 14, 25, 33]
# Top 7 peaks, $W_L$ sin: [51, 43, 37, 25, 8, 14, 6]

# %% [markdown]
# seed = 5 | key frequencies of WL = 37, 43, 51

# %%
analyze_unembd()
plt.show()

# %%
plot_metrics_progress_measure()
plt.show()

# %%
plot_metrics_progress_measure_wd0()
plt.show()
